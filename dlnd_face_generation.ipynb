# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """
    trans=transforms.Compose([transforms.Resize(image_size),transforms.ToTensor()])
    dat=datasets.ImageFolder(data_dir,transform=trans)
    img_Data=torch.utils.data.DataLoader(dataset=dat,batch_size=batch_size,shuffle=True)
    # TODO: Implement function and return a dataloader
    
    return img_Data

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 32
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min,max=feature_range
    x = x*(max-min)+min
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.8745)
# Max:  tensor(1.)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim=conv_dim
        self.conv1=nn.Conv2d(3,conv_dim,kernel_size=4,stride=2,padding=1)#16x16
        #self.conv2=nn.Conv2d(conv_dim,conv_dim*2,kernel_size=3,stride=1,padding=1,bias=False)#16x16
        #self.btNorm2=nn.BatchNorm2d(conv_dim*2)
        self.conv3=nn.Conv2d(conv_dim*1,conv_dim*4,kernel_size=4,stride=2,padding=1,bias=False)#8x8was convdim*2
        self.btNorm3=nn.BatchNorm2d(conv_dim*4)
        self.conv4=nn.Conv2d(conv_dim*4,conv_dim*6,kernel_size=4,stride=2,padding=1,bias=False)#4x4
        self.btNorm4=nn.BatchNorm2d(conv_dim*6)
        self.fc1=nn.Linear(conv_dim*6*4*4,1)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x=self.conv1(x)
        x=F.leaky_relu(x,0.15)
        #x=self.btNorm2(self.conv2(x))
        #x=F.leaky_relu(x,0.15)
        x=self.btNorm3(self.conv3(x))
        x=F.leaky_relu(x,0.15)
        x=self.btNorm4(self.conv4(x))
        x=F.leaky_relu(x,0.15)
        x=x.view(-1,self.conv_dim*6*4*4)
        x=self.fc1(x)
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim=conv_dim
        self.fc1=nn.Linear(z_size,conv_dim*6*4*4)
        self.deConv1=nn.ConvTranspose2d(conv_dim*6,conv_dim*4,kernel_size=4,stride=2,padding=1,bias=False)
        self.btNorm1=nn.BatchNorm2d(conv_dim*4)
        self.deConv2=nn.ConvTranspose2d(conv_dim*4,conv_dim*2,kernel_size=4,stride=2,padding=1,bias=False)
        self.btNorm2=nn.BatchNorm2d(conv_dim*2)
        self.deConv3=nn.ConvTranspose2d(conv_dim*2,conv_dim*1,kernel_size=3,stride=1,padding=1,bias=False)
        self.btNorm3=nn.BatchNorm2d(conv_dim*1)
        self.deConv4=nn.ConvTranspose2d(conv_dim*1,3,kernel_size=4,stride=2,padding=1,bias=False)
        #self.btNorm4=nn.BatchNorm2d(conv_dim*1*32*32)
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x=F.relu(self.fc1(x))
        x=x.view(-1,self.conv_dim*6, 4, 4)
        x=F.relu(self.btNorm1(self.deConv1(x)))
        x=F.relu(self.btNorm2(self.deConv2(x)))
        x=F.relu(self.btNorm3(self.deConv3(x)))
        x=F.tanh((self.deConv4(x)))
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# D:\Workspace\CS_IDEs\Python_R\Python\Anaconda3\envs\DeepLearning\lib\site-packages\torch\nn\functional.py:1374: UserWarning: nn.functional.tanh is deprecated. Use torch.tanh instead.
#   warnings.warn("nn.functional.tanh is deprecated. Use torch.tanh instead.")
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if hasattr(m, 'weight') and (classname.find('Conv') != -1 or classname.find('Linear') != -1):
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
        if hasattr(m, 'bias') and m.bias is not None:
            torch.nn.init.constant_(m.bias.data, 0.0)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 64
g_conv_dim = 64
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Conv2d(3, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#   (conv3): Conv2d(64, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (btNorm3): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (conv4): Conv2d(256, 384, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (btNorm4): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=6144, out_features=1, bias=True)
# )
#
# Generator(
#   (fc1): Linear(in_features=100, out_features=6144, bias=True)
#   (deConv1): ConvTranspose2d(384, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (btNorm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deConv2): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (btNorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deConv3): ConvTranspose2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (btNorm3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (deConv4): ConvTranspose2d(64, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out,smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_Dim=D_out.size(0)
    labels=torch.ones(batch_Dim)
    if smooth:
        labels=labels*0.9
    if train_on_gpu:
        labels = labels.cuda()
    criterion=nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(),labels.squeeze())
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_Dim=D_out.size(0)
    labels=torch.zeros(batch_Dim)
    if train_on_gpu:
        labels = labels.cuda()
    criterion=nn.BCEWithLogitsLoss()
    loss = criterion(D_out.squeeze(),labels.squeeze())

    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# Create optimizers for the discriminator D and generator G
lr=0.0002
momentMin=0.5
momentMax=0.999
d_optimizer = optim.Adam(D.parameters(),lr, [momentMin, momentMax])
g_optimizer = optim.Adam(G.parameters(),lr, [momentMin, momentMax])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            if train_on_gpu:
                real_images=real_images.cuda()
            real_Out=D(real_images)
            r_Loss=real_loss(real_Out,smooth=True)
            rnd_Noise=np.random.uniform(-1,1,size=(batch_size,z_size))
            rnd_Noise=torch.from_numpy(rnd_Noise).float()
            if train_on_gpu:
                rnd_Noise=rnd_Noise.cuda()
            fkImg=G(rnd_Noise)
            fake_Out=D(fkImg)
            f_Loss=fake_loss(fake_Out)
            d_loss = r_Loss+f_Loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            rnd_Noise2=np.random.uniform(-1,1,size=(batch_size,z_size))
            rnd_Noise2=torch.from_numpy(rnd_Noise2).float()
            if train_on_gpu:
                rnd_Noise2=rnd_Noise2.cuda()
            g_optimizer.zero_grad()
            fkImg2=G(rnd_Noise2)
            gen_Out=D(fkImg2)
            g_loss=real_loss(gen_Out)
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 15


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   15] | d_loss: 1.5040 | g_loss: 1.5599
# Epoch [    1/   15] | d_loss: 0.4240 | g_loss: 4.3067
# Epoch [    1/   15] | d_loss: 0.4623 | g_loss: 4.7554
# Epoch [    1/   15] | d_loss: 0.4938 | g_loss: 4.9802
# Epoch [    1/   15] | d_loss: 0.6548 | g_loss: 5.3113
# Epoch [    1/   15] | d_loss: 0.6958 | g_loss: 3.0268
# Epoch [    1/   15] | d_loss: 0.6713 | g_loss: 2.9363
# Epoch [    1/   15] | d_loss: 0.6723 | g_loss: 3.8764
# Epoch [    1/   15] | d_loss: 0.7201 | g_loss: 3.2143
# Epoch [    1/   15] | d_loss: 0.8552 | g_loss: 3.7605
# Epoch [    1/   15] | d_loss: 0.7898 | g_loss: 2.8378
# Epoch [    1/   15] | d_loss: 1.0099 | g_loss: 2.7062
# Epoch [    1/   15] | d_loss: 0.8198 | g_loss: 2.6914
# Epoch [    1/   15] | d_loss: 0.9253 | g_loss: 3.8142
# Epoch [    1/   15] | d_loss: 0.6407 | g_loss: 3.0371
# Epoch [    1/   15] | d_loss: 0.9797 | g_loss: 2.4153
# Epoch [    2/   15] | d_loss: 1.2197 | g_loss: 2.0206
# Epoch [    2/   15] | d_loss: 0.9764 | g_loss: 2.6344
# Epoch [    2/   15] | d_loss: 1.3969 | g_loss: 3.3691
# Epoch [    2/   15] | d_loss: 1.1238 | g_loss: 2.2408
# Epoch [    2/   15] | d_loss: 1.0043 | g_loss: 1.8319
# Epoch [    2/   15] | d_loss: 1.0463 | g_loss: 1.7302
# Epoch [    2/   15] | d_loss: 0.9490 | g_loss: 1.8631
# Epoch [    2/   15] | d_loss: 1.1407 | g_loss: 1.5624
# Epoch [    2/   15] | d_loss: 0.9600 | g_loss: 1.6618
# Epoch [    2/   15] | d_loss: 0.9759 | g_loss: 2.2567
# Epoch [    2/   15] | d_loss: 1.0781 | g_loss: 3.0867
# Epoch [    2/   15] | d_loss: 0.8612 | g_loss: 2.4729
# Epoch [    2/   15] | d_loss: 0.9722 | g_loss: 1.4996
# Epoch [    2/   15] | d_loss: 1.0905 | g_loss: 2.4039
# Epoch [    2/   15] | d_loss: 1.1224 | g_loss: 2.2996
# Epoch [    2/   15] | d_loss: 0.8872 | g_loss: 2.4333
# Epoch [    3/   15] | d_loss: 1.0758 | g_loss: 1.9752
# Epoch [    3/   15] | d_loss: 0.9541 | g_loss: 2.1220
# Epoch [    3/   15] | d_loss: 1.0302 | g_loss: 2.0843
# Epoch [    3/   15] | d_loss: 0.9566 | g_loss: 1.6793
# Epoch [    3/   15] | d_loss: 0.9803 | g_loss: 1.2243
# Epoch [    3/   15] | d_loss: 0.9722 | g_loss: 1.4990
# Epoch [    3/   15] | d_loss: 1.0265 | g_loss: 1.5763
# Epoch [    3/   15] | d_loss: 1.2443 | g_loss: 1.5483
# Epoch [    3/   15] | d_loss: 1.1118 | g_loss: 1.8601
# Epoch [    3/   15] | d_loss: 1.0788 | g_loss: 1.4302
# Epoch [    3/   15] | d_loss: 1.0942 | g_loss: 1.5877
# Epoch [    3/   15] | d_loss: 0.8794 | g_loss: 2.4978
# Epoch [    3/   15] | d_loss: 0.9811 | g_loss: 1.8980
# Epoch [    3/   15] | d_loss: 0.9134 | g_loss: 2.0260
# Epoch [    3/   15] | d_loss: 1.0395 | g_loss: 1.7729
# Epoch [    3/   15] | d_loss: 1.0000 | g_loss: 1.9547
# Epoch [    4/   15] | d_loss: 1.2834 | g_loss: 1.1651
# Epoch [    4/   15] | d_loss: 1.0128 | g_loss: 1.5663
# Epoch [    4/   15] | d_loss: 1.1738 | g_loss: 1.4472
# Epoch [    4/   15] | d_loss: 0.9342 | g_loss: 2.2586
# Epoch [    4/   15] | d_loss: 1.0205 | g_loss: 2.0526
# Epoch [    4/   15] | d_loss: 1.2996 | g_loss: 1.3220
# Epoch [    4/   15] | d_loss: 1.0925 | g_loss: 2.0727
# Epoch [    4/   15] | d_loss: 0.9984 | g_loss: 1.8010
# Epoch [    4/   15] | d_loss: 1.1756 | g_loss: 2.2508
# Epoch [    4/   15] | d_loss: 1.1042 | g_loss: 1.8337
# Epoch [    4/   15] | d_loss: 0.7803 | g_loss: 1.6266
# Epoch [    4/   15] | d_loss: 0.8810 | g_loss: 2.3548
# Epoch [    4/   15] | d_loss: 1.3465 | g_loss: 1.3220
# Epoch [    4/   15] | d_loss: 0.9644 | g_loss: 1.6555
# Epoch [    4/   15] | d_loss: 1.0847 | g_loss: 1.4392
# Epoch [    4/   15] | d_loss: 0.9317 | g_loss: 1.6775
# Epoch [    5/   15] | d_loss: 1.1030 | g_loss: 1.6803
# Epoch [    5/   15] | d_loss: 1.0488 | g_loss: 1.5204
# Epoch [    5/   15] | d_loss: 1.1437 | g_loss: 1.8367
# Epoch [    5/   15] | d_loss: 1.2572 | g_loss: 1.4861
# Epoch [    5/   15] | d_loss: 1.0762 | g_loss: 1.8715
# Epoch [    5/   15] | d_loss: 1.1457 | g_loss: 1.2386
# Epoch [    5/   15] | d_loss: 1.0928 | g_loss: 1.6939
# Epoch [    5/   15] | d_loss: 1.4780 | g_loss: 0.9726
# Epoch [    5/   15] | d_loss: 1.0220 | g_loss: 1.4388
# Epoch [    5/   15] | d_loss: 1.2923 | g_loss: 2.2708
# Epoch [    5/   15] | d_loss: 0.9979 | g_loss: 1.5247
# Epoch [    5/   15] | d_loss: 1.0234 | g_loss: 1.3711
# Epoch [    5/   15] | d_loss: 1.1845 | g_loss: 1.7596
# Epoch [    5/   15] | d_loss: 0.9514 | g_loss: 2.0407
# Epoch [    5/   15] | d_loss: 1.2543 | g_loss: 1.7866
# Epoch [    5/   15] | d_loss: 1.4029 | g_loss: 1.9125
# Epoch [    6/   15] | d_loss: 1.0168 | g_loss: 1.8022
# Epoch [    6/   15] | d_loss: 1.1746 | g_loss: 1.7727
# Epoch [    6/   15] | d_loss: 1.1166 | g_loss: 1.8393
# Epoch [    6/   15] | d_loss: 1.0369 | g_loss: 1.0690
# Epoch [    6/   15] | d_loss: 1.2729 | g_loss: 1.3281
# Epoch [    6/   15] | d_loss: 1.1915 | g_loss: 1.8854
# Epoch [    6/   15] | d_loss: 1.0813 | g_loss: 1.7361
# Epoch [    6/   15] | d_loss: 1.0500 | g_loss: 1.4242
# Epoch [    6/   15] | d_loss: 1.1125 | g_loss: 1.9889
# Epoch [    6/   15] | d_loss: 0.9192 | g_loss: 2.0226
# Epoch [    6/   15] | d_loss: 1.1454 | g_loss: 1.5169
# Epoch [    6/   15] | d_loss: 0.9683 | g_loss: 1.5817
# Epoch [    6/   15] | d_loss: 1.1662 | g_loss: 1.5128
# Epoch [    6/   15] | d_loss: 1.1391 | g_loss: 1.5934
# Epoch [    6/   15] | d_loss: 1.1627 | g_loss: 1.3730
# Epoch [    6/   15] | d_loss: 1.2296 | g_loss: 1.6244
# Epoch [    7/   15] | d_loss: 1.5753 | g_loss: 2.0155
# Epoch [    7/   15] | d_loss: 1.1496 | g_loss: 1.4920
# Epoch [    7/   15] | d_loss: 1.3588 | g_loss: 1.4156
# Epoch [    7/   15] | d_loss: 1.1742 | g_loss: 1.3185
# Epoch [    7/   15] | d_loss: 1.1961 | g_loss: 1.4700
# Epoch [    7/   15] | d_loss: 1.1521 | g_loss: 1.5504
# Epoch [    7/   15] | d_loss: 1.2828 | g_loss: 1.0031
# Epoch [    7/   15] | d_loss: 0.9502 | g_loss: 1.0742
# Epoch [    7/   15] | d_loss: 1.3530 | g_loss: 1.5886
# Epoch [    7/   15] | d_loss: 1.1374 | g_loss: 1.3245
# Epoch [    7/   15] | d_loss: 1.0428 | g_loss: 1.4105
# Epoch [    7/   15] | d_loss: 1.2071 | g_loss: 1.5236
# Epoch [    7/   15] | d_loss: 0.9832 | g_loss: 1.5548
# Epoch [    7/   15] | d_loss: 1.2363 | g_loss: 1.3960
# Epoch [    7/   15] | d_loss: 1.0649 | g_loss: 1.3711
# Epoch [    7/   15] | d_loss: 1.1951 | g_loss: 1.2644
# Epoch [    8/   15] | d_loss: 1.1737 | g_loss: 1.5797
# Epoch [    8/   15] | d_loss: 1.5155 | g_loss: 1.2940
# Epoch [    8/   15] | d_loss: 1.1443 | g_loss: 0.9131
# Epoch [    8/   15] | d_loss: 1.3134 | g_loss: 1.4889
# Epoch [    8/   15] | d_loss: 1.1924 | g_loss: 1.3541
# Epoch [    8/   15] | d_loss: 1.1947 | g_loss: 1.3610
# Epoch [    8/   15] | d_loss: 1.1046 | g_loss: 1.8147
# Epoch [    8/   15] | d_loss: 1.1080 | g_loss: 1.7695
# Epoch [    8/   15] | d_loss: 1.1066 | g_loss: 1.6300
# Epoch [    8/   15] | d_loss: 1.1254 | g_loss: 1.3963
# Epoch [    8/   15] | d_loss: 0.9707 | g_loss: 1.4171
# Epoch [    8/   15] | d_loss: 1.2390 | g_loss: 1.4926
# Epoch [    8/   15] | d_loss: 1.0881 | g_loss: 1.6597
# Epoch [    8/   15] | d_loss: 1.1691 | g_loss: 1.3605
# Epoch [    8/   15] | d_loss: 1.2380 | g_loss: 1.5724
# Epoch [    8/   15] | d_loss: 1.1354 | g_loss: 1.3458
# Epoch [    9/   15] | d_loss: 0.9742 | g_loss: 1.5273
# Epoch [    9/   15] | d_loss: 1.2016 | g_loss: 1.4580
# Epoch [    9/   15] | d_loss: 0.9244 | g_loss: 1.5615
# Epoch [    9/   15] | d_loss: 1.2626 | g_loss: 1.7972
# Epoch [    9/   15] | d_loss: 1.2626 | g_loss: 1.5706
# Epoch [    9/   15] | d_loss: 1.0522 | g_loss: 1.4003
# Epoch [    9/   15] | d_loss: 1.3631 | g_loss: 0.9930
# Epoch [    9/   15] | d_loss: 1.2522 | g_loss: 1.7535
# Epoch [    9/   15] | d_loss: 1.1785 | g_loss: 1.4756
# Epoch [    9/   15] | d_loss: 1.2145 | g_loss: 1.3436
# Epoch [    9/   15] | d_loss: 0.9975 | g_loss: 1.2821
# Epoch [    9/   15] | d_loss: 1.0879 | g_loss: 1.1456
# Epoch [    9/   15] | d_loss: 1.0431 | g_loss: 1.4695
# Epoch [    9/   15] | d_loss: 1.1250 | g_loss: 1.7748
# Epoch [    9/   15] | d_loss: 1.4167 | g_loss: 1.0782
# Epoch [    9/   15] | d_loss: 1.1565 | g_loss: 1.2780
# Epoch [   10/   15] | d_loss: 1.0942 | g_loss: 1.2889
# Epoch [   10/   15] | d_loss: 1.2138 | g_loss: 1.1683
# Epoch [   10/   15] | d_loss: 1.1838 | g_loss: 0.9588
# Epoch [   10/   15] | d_loss: 1.2756 | g_loss: 0.9528
# Epoch [   10/   15] | d_loss: 1.1722 | g_loss: 1.8217
# Epoch [   10/   15] | d_loss: 1.0280 | g_loss: 1.9609
# Epoch [   10/   15] | d_loss: 1.0874 | g_loss: 1.1216
# Epoch [   10/   15] | d_loss: 0.9504 | g_loss: 1.3887
# Epoch [   10/   15] | d_loss: 1.1368 | g_loss: 1.9620
# Epoch [   10/   15] | d_loss: 1.3688 | g_loss: 1.5339
# Epoch [   10/   15] | d_loss: 1.1280 | g_loss: 1.6613
# Epoch [   10/   15] | d_loss: 1.0012 | g_loss: 1.6672
# Epoch [   10/   15] | d_loss: 1.2039 | g_loss: 1.4681
# Epoch [   10/   15] | d_loss: 1.3310 | g_loss: 1.6828
# Epoch [   10/   15] | d_loss: 1.2640 | g_loss: 1.4633
# Epoch [   10/   15] | d_loss: 1.2145 | g_loss: 1.9794
# Epoch [   11/   15] | d_loss: 1.1467 | g_loss: 1.0824
# Epoch [   11/   15] | d_loss: 1.0093 | g_loss: 1.3628
# Epoch [   11/   15] | d_loss: 1.0632 | g_loss: 1.8675
# Epoch [   11/   15] | d_loss: 1.5898 | g_loss: 2.1034
# Epoch [   11/   15] | d_loss: 1.1632 | g_loss: 1.8766
# Epoch [   11/   15] | d_loss: 1.0924 | g_loss: 1.2722
# Epoch [   11/   15] | d_loss: 1.3377 | g_loss: 0.9546
# Epoch [   11/   15] | d_loss: 1.1787 | g_loss: 2.0116
# Epoch [   11/   15] | d_loss: 1.2835 | g_loss: 1.7406
# Epoch [   11/   15] | d_loss: 1.3177 | g_loss: 1.6301
# Epoch [   11/   15] | d_loss: 1.1055 | g_loss: 2.0750
# Epoch [   11/   15] | d_loss: 1.1247 | g_loss: 1.2804
# Epoch [   11/   15] | d_loss: 1.2721 | g_loss: 1.3250
# Epoch [   11/   15] | d_loss: 1.1550 | g_loss: 1.0198
# Epoch [   11/   15] | d_loss: 1.3991 | g_loss: 1.6525
# Epoch [   11/   15] | d_loss: 1.5883 | g_loss: 1.0971
# Epoch [   12/   15] | d_loss: 1.0695 | g_loss: 1.3296
# Epoch [   12/   15] | d_loss: 1.0398 | g_loss: 1.4067
# Epoch [   12/   15] | d_loss: 1.0489 | g_loss: 1.9314
# Epoch [   12/   15] | d_loss: 1.0755 | g_loss: 1.4621
# Epoch [   12/   15] | d_loss: 1.0299 | g_loss: 1.1154
# Epoch [   12/   15] | d_loss: 1.1475 | g_loss: 1.5380
# Epoch [   12/   15] | d_loss: 0.9930 | g_loss: 1.5597
# Epoch [   12/   15] | d_loss: 1.2732 | g_loss: 1.2947
# Epoch [   12/   15] | d_loss: 1.0184 | g_loss: 1.2494
# Epoch [   12/   15] | d_loss: 1.3173 | g_loss: 1.4465
# Epoch [   12/   15] | d_loss: 1.3297 | g_loss: 2.0561
# Epoch [   12/   15] | d_loss: 1.1120 | g_loss: 0.8931
# Epoch [   12/   15] | d_loss: 0.8044 | g_loss: 1.7488
# Epoch [   12/   15] | d_loss: 1.0062 | g_loss: 1.1526
# Epoch [   12/   15] | d_loss: 1.1383 | g_loss: 1.5145
# Epoch [   12/   15] | d_loss: 1.2843 | g_loss: 1.5694
# Epoch [   13/   15] | d_loss: 1.1497 | g_loss: 1.2878
# Epoch [   13/   15] | d_loss: 1.0685 | g_loss: 1.5871
# Epoch [   13/   15] | d_loss: 1.2304 | g_loss: 1.2245
# Epoch [   13/   15] | d_loss: 1.0547 | g_loss: 1.5443
# Epoch [   13/   15] | d_loss: 1.1759 | g_loss: 1.6221
# Epoch [   13/   15] | d_loss: 1.1286 | g_loss: 1.6450
# Epoch [   13/   15] | d_loss: 1.3013 | g_loss: 1.2457
# Epoch [   13/   15] | d_loss: 1.0555 | g_loss: 1.7895
# Epoch [   13/   15] | d_loss: 1.3652 | g_loss: 1.3763
# Epoch [   13/   15] | d_loss: 1.0874 | g_loss: 1.6027
# Epoch [   13/   15] | d_loss: 1.2251 | g_loss: 1.3727
# Epoch [   13/   15] | d_loss: 1.1960 | g_loss: 1.3592
# Epoch [   13/   15] | d_loss: 1.1979 | g_loss: 1.1829
# Epoch [   13/   15] | d_loss: 1.2898 | g_loss: 1.4013
# Epoch [   13/   15] | d_loss: 1.0396 | g_loss: 1.5585
# Epoch [   13/   15] | d_loss: 1.0559 | g_loss: 1.4552
# Epoch [   14/   15] | d_loss: 1.3175 | g_loss: 1.7409
# Epoch [   14/   15] | d_loss: 0.9647 | g_loss: 1.5596
# Epoch [   14/   15] | d_loss: 0.8978 | g_loss: 1.6439
# Epoch [   14/   15] | d_loss: 0.9747 | g_loss: 1.4836
# Epoch [   14/   15] | d_loss: 0.9841 | g_loss: 1.6893
# Epoch [   14/   15] | d_loss: 0.9811 | g_loss: 1.2743
# Epoch [   14/   15] | d_loss: 1.2884 | g_loss: 1.7084
# Epoch [   14/   15] | d_loss: 1.3591 | g_loss: 1.9314
# Epoch [   14/   15] | d_loss: 1.1994 | g_loss: 1.5905
# Epoch [   14/   15] | d_loss: 1.2113 | g_loss: 1.8567
# Epoch [   14/   15] | d_loss: 0.9991 | g_loss: 1.3792
# Epoch [   14/   15] | d_loss: 1.3390 | g_loss: 1.8802
# Epoch [   14/   15] | d_loss: 1.0302 | g_loss: 1.9066
# Epoch [   14/   15] | d_loss: 1.0716 | g_loss: 1.4151
# Epoch [   14/   15] | d_loss: 1.2148 | g_loss: 1.3949
# Epoch [   14/   15] | d_loss: 1.2370 | g_loss: 0.9629
# Epoch [   15/   15] | d_loss: 1.4756 | g_loss: 1.9589
# Epoch [   15/   15] | d_loss: 0.9887 | g_loss: 1.0768
# Epoch [   15/   15] | d_loss: 1.0564 | g_loss: 1.1049
# Epoch [   15/   15] | d_loss: 0.9288 | g_loss: 1.6824
# Epoch [   15/   15] | d_loss: 0.9306 | g_loss: 1.2148
# Epoch [   15/   15] | d_loss: 1.1110 | g_loss: 1.7164
# Epoch [   15/   15] | d_loss: 1.2006 | g_loss: 1.9749
# Epoch [   15/   15] | d_loss: 0.9638 | g_loss: 1.4375
# Epoch [   15/   15] | d_loss: 1.0903 | g_loss: 2.0362
# Epoch [   15/   15] | d_loss: 1.0296 | g_loss: 1.8735
# Epoch [   15/   15] | d_loss: 1.1004 | g_loss: 1.5558
# Epoch [   15/   15] | d_loss: 1.0422 | g_loss: 1.6954
# Epoch [   15/   15] | d_loss: 1.2083 | g_loss: 1.6926
# Epoch [   15/   15] | d_loss: 0.9254 | g_loss: 1.6759
# Epoch [   15/   15] | d_loss: 0.9178 | g_loss: 2.1800
# Epoch [   15/   15] | d_loss: 1.1287 | g_loss: 1.4579

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:**
# My first few trials used an extra layer in the descriminator and ran for up to 100 epochs, this got terrible results and I made several attempts to improve adjusting the learning rate and removing the mentioned layer. Turns out when i was creating my random noise sample I was only creating one sample, not batch_size samples. In short I am an idiot. It worked fine after that.
#
# The generated samples all are definitely faces, however some do not appear complete, as if two faces are stitched together. I could increase the generator size and train for longer, this may provide better results. The optimization is essentially the same as all the parameters from the gans paper, tweaking them could potentially provide some results. The code seems to increase in the final epochs, reducing the epochs by 1 or 2 might help.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
